# %% [markdown]
# ### Variables rules

# %%
Pooja =45

# %%
pooja =45

# %%
@Pooja =45
# Out:
#   Cell In[3], line 1
#     @Pooja =45
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
-Pooja =45
# Out:
#   Cell In[4], line 1
#     -Pooja =45
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
_Pooja =45

# %%
Pooja-raskar =45
# Out:
#   Cell In[6], line 1
#     Pooja-raskar =45
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
Pooja_raskar =45

# %%
1Pooja =45
# Out:
#   Cell In[8], line 1
#     1Pooja =45
#     ^
# SyntaxError: invalid decimal literal

# %%
@Pooja = 45
# Out:
#   Cell In[9], line 1
#     @Pooja = 45
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
item_name = "Sugar"
Item_quantity = 10
Item_price = 43
Total_bill = Item_quantity * Item_price
print(item_name)
print('Customer Total bill is',Total_bill)
# Out:
# Sugar
# Customer Total bill is 430

# %%
Product_name = input("Enter your item name :")
# Out:
# Enter your item name : Sugar

# %%
print (type(Product_name))
# Out:
# <class 'str'>

# %%
Product_quantity = float (input("Enter the Quantity of Product :"))
# Out:
# Enter the Quantity of Product : 34

# %%
Product_price = float(input("Enter the price of Product :"))
# Out:
# Enter the price of Product : 5

# %%
Product_quantity = float(input("Enter the Quantity of Product: "))
Product_price = float(input("Enter the Price of Product: "))

Total_Bill = Product_price * Product_quantity
print("Total Bill =", Total_Bill)
# Out:
# Enter the Quantity of Product:  5
# Enter the Price of Product:  55
# Total Bill = 275.0

# %% [markdown]
# ### Single line comments

# %%
#slg='s-single l-line c-comment

# %% [markdown]
# ### Multi line comments

# %%
#"""
#This my is House
#"""

# %%
#my name is pooja
#i am in final year
# my dept is ece

# %%
"""
This my is House
"""
# Out:
# '\nThis my is House\n'

# %% [markdown]
# ### Docstring(Documentation string)

# %%
def greet (name):
    """ this function greets user by name"""
    print(f"Hello,{name}")
